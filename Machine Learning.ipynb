# %%
import sqlite3
conn = sqlite3.connect('Mozartt.db')
cur = conn.cursor()
cur.execute("SELECT 희망일시, 거리, 대기시간 FROM calltaxi")
rows = cur.fetchall()
haha =[]
for row in rows:
    haha.append((row[0]))

# %%
time = []
for a in haha:
    hr = int(a[11])*10+int(a[12])
    mn = int(a[14])*10+int(a[15])
    se = int(a[17])*10+int(a[18])
    b = hr*3600+mn*60+se
    time.append(b)

# %% [markdown]
# ## 희망일시: time, 거리: long,              Target --> 대기시간: cool

# %%
long = []
for row in rows:
    long.append((row[1]))

# %%
for row in rows:
    haha.append((row[2]))
cool=[]
for a in haha:
    hr = int(a[0])*10+int(a[1])
    mn = int(a[3])*10+int(a[4])
    se = int(a[6])*10+int(a[7])
    b = hr*3600+mn*60+se
    cool.append(b)

# %%
len(time)
# Out:
# 102118

# %%
D2=[]
for a in range(len(time)):
    D2.append([time[a],long[a]])

# %%
X
# Out:
# array([[1.08000000e+03, 9.51117379e-02],
#        [1.26000000e+03, 3.35977316e-01],
#        [1.50000000e+03, 6.16601547e-02],
#        ...,
#        [4.24200000e+04, 0.00000000e+00],
#        [4.32600000e+04, 4.36893691e-01],
#        [4.45200000e+04, 1.54621188e-01]])

# %%
y
# Out:
# [3264,
#  3861,
#  4853,
#  5274,
#  2894,
#  2333,
#  2149,
#  3102,
#  4213,
#  3268,
#  174,
#  2678,
#  3408,
#  1644,
#  2905,
#  0,
#  1204,
#  1379,
#  1306,
#  1214,
#  658,
#  1116,
#  982,
#  1823,
#  1896,
#  1682,
#  2929,
#  0,
#  1675,
#  653,
#  1238,
#  2356,
#  1706,
#  1022,
#  1457,
#  5334,
#  5552,
#  844,
#  1298,
#  1288,
#  760,
#  1727,
#  1551,
#  1029,
#  946,
#  1461,
#  1512,
#  1283,
#  1422,
#  2606,
#  1559,
#  2179,
#  1576,
#  1451,
#  1759,
#  1914,
#  3041,
#  1906,
#  3399,
#  2259,
#  1622,
#  1601,
#  1408,
#  1530,
#  3473,
#  3802,
#  1671,
#  2373,
#  3079,
#  1290,
#  1102,
#  4435,
#  1311,
#  1013,
#  1854,
#  4061,
#  1623,
#  801,
#  1522,
#  1563,
#  2093,
#  1957,
#  3824,
#  1091,
#  3261,
#  4488,
#  1934,
#  1833,
#  2171,
#  1325,
#  1972,
#  3679,
#  1475,
#  4332,
#  2030,
#  3946,
#  2512,
#  2757,
#  2111,
#  3976,
#  3699,
#  1543,
#  1620,
#  1802,
#  1426,
#  1404,
#  1701,
#  1867,
#  3390,
#  2005,
#  3683,
#  2576,
# ...

# %%
y=np.array(cool)

# %%
# X=np.array(time)
# X=np.array(long)
X=np.array(D2)

# %%
import numpy as np

# %%
import mglearn

# %%
from sklearn.model_selection import train_test_split

# %%
import sklearn
from sklearn.neighbors import KNeighborsRegressor

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2)

# %%
reg = KNeighborsRegressor(n_neighbors=6)

# %%
reg.fit(X_train, y_train)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=6, p=2,
#           weights='uniform')

# %%
reg.predict(X_test)
# Out:
# array([4885.33333333, 5329.33333333, 4502.66666667, ..., 6721.83333333,
#        2336.83333333, 4365.5       ])

# %%
reg.score(X_test, y_test)
# Out:
# 0.25904373942606074

# %%
print("test set prediction:\n".format(reg.score(X_test,y_test)))
# Out:
# test set prediction:

# %%
X, y = mglearn.datasets.make_wave(n_samples=40)

# %% [markdown]
# ## RIDGE

# %%
from sklearn.linear_model import Ridge

# %%
ridge = Ridge().fit(X_train, y_train)

# %%
ridge.score(X_train, y_train)
# Out:
# 0.011765840088983624

# %% [markdown]
# ## Lasso

# %%
from sklearn.linear_model import Lasso

# %%
lasso = Lasso().fit(X_train, y_train)

# %%
lasso.score(X_train, y_train)
# Out:
# 0.011720225679464402

# %% [markdown]
# ### Gradient Boosting Regression

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
gbrt = GradientBoostingRegressor(random_state=0)

# %%
gbrt.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#              learning_rate=0.1, loss='ls', max_depth=3, max_features=None,
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=100, presort='auto', random_state=0,
#              subsample=1.0, verbose=0, warm_start=False)

# %%
gbrt.score(X_train, y_train)
# Out:
# 0.2935747654831692

# %% [markdown]
# ### Support Vector Machine

# %%
from sklearn.svm import SVR

# %%
svm = SVR(kernel='rbf', C=10, gamma=0.1).fit(X,y)

# %%
svm.score(X_train, y_train)
